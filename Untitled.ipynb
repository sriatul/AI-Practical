# %%
import pandas as pd
df = pd.read_csv('human.csv')
df
# Out:
#    height gender
# 0     152      f
# 1     165      m
# 2     167      m
# 3     172      m
# 4     171      m
# 5     156      f
# 6     160      f
# 7     173      m
# 8     169      m
# 9     155      f

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a=df

# %%
model.fit(a.drop('gender', axis= 'columns'), df.gender)
# Out:
# LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(a.drop('gender', axis ='columns') a.gender)
# Out:
#   Cell In[12], line 1
#     model.fit(a.drop('gender', axis ='columns') a.gender)
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
model.predict([[152]])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.predict([[152]])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:382, in LinearClassifierMixin.predict(self, X)
#     368 """
#     369 Predict class labels for samples in X.
#     370
#    (...)
#     379     Vector containing the class labels for each sample.
#     380 """
#     381 xp, _ = get_namespace(X)
# --> 382 scores = self.decision_function(X)
#     383 if len(scores.shape) == 1:
#     384     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:360, in LinearClassifierMixin.decision_function(self, X)
#     341 def decision_function(self, X):
#     342     """
#     343     Predict confidence scores for samples.
#     344
#    (...)
#     358         this class would be predicted.
#     359     """
# --> 360     check_is_fitted(self)
#     361     xp, _ = get_namespace(X)
#     363     X = self._validate_data(X, accept_sparse="csr", reset=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1632, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1629     raise TypeError("%s is not an estimator instance." % (estimator))
#    1631 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1632     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
x = int( input('height'))

# %%
y  = model.predict([[x]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y  = model.predict([[x]])
#
# NameError: name 'model' is not defined

# %%
if(y):print('male')
else:print("Female')
# Out:
#   Cell In[3], line 2
#     else:print("Female')
#                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
x = int( input('height'))
y  = model.predict([[x]])
if(y):print('male')
else:print("Female')
# Out:
#   Cell In[4], line 4
#     else:print("Female')
#                ^
# SyntaxError: unterminated string literal (detected at line 4)
