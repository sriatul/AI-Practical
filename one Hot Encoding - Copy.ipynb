# %%
import pandas as pd
df= pd.read_csv('data.csv')
df.head(1)
# Out:
#    area(sq ft) localilty    price
# 0          550   station  1500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   area(sq ft)  7 non-null      int64
#  1   localilty    7 non-null      object
#  2   price        7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 296.0+ bytes

# %%
#dummy values

# %%
dummy = pd.get_dummies(df.localilty)
dummy
# Out:
#    center    old  station
# 0   False  False     True
# 1    True  False    False
# 2   False   True    False
# 3    True  False    False
# 4    True  False    False
# 5   False   True    False
# 6   False  False     True

# %%
merged =pd.concat([df, dummy], axis = 'columns')
merged
# Out:
#    area(sq ft) localilty    price  center    old  station
# 0          550   station  1500000   False  False     True
# 1          600    center  1200000    True  False    False
# 2          650       old   800000   False   True    False
# 3          900    center  3000000    True  False    False
# 4         1000    center  4000000    True  False    False
# 5          800       old  1000000   False   True    False
# 6          900   station  2000000   False  False     True

# %%
a =merged.drop(['localilty'],axis = 'columns')
a
# Out:
#    area(sq ft)    price  center    old  station
# 0          550  1500000   False  False     True
# 1          600  1200000    True  False    False
# 2          650   800000   False   True    False
# 3          900  3000000    True  False    False
# 4         1000  4000000    True  False    False
# 5          800  1000000   False   True    False
# 6          900  2000000   False  False     True

# %%
a.replace([True , False], [1,0] , inplace=True)
a
# Out:
# C:\Users\Accer\AppData\Local\Temp\ipykernel_5208\2573879642.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   a.replace([True , False], [1,0] , inplace=True)
#    area(sq ft)    price  center  old  station
# 0          550  1500000       0    0        1
# 1          600  1200000       1    0        0
# 2          650   800000       0    1        0
# 3          900  3000000       1    0        0
# 4         1000  4000000       1    0        0
# 5          800  1000000       0    1        0
# 6          900  2000000       0    0        1

# %%
#One hot Encoding

# %%
import pandas as pd
df= pd.read_csv('data.csv')
df.head(1)
# Out:
#    area(sq ft) localilty    price
# 0          550   station  1500000

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a = df

# %%
a.localilty = le.fit_transform(a.localilty)
a
# Out:
#    area(sq ft)  localilty    price
# 0          550          2  1500000
# 1          600          0  1200000
# 2          650          1   800000
# 3          900          0  3000000
# 4         1000          0  4000000
# 5          800          1  1000000
# 6          900          2  2000000

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression

# %%
model
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.fit(a.drop('price', axis='columns'), a.price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5208\2261756472.py in ?()
# ----> 1 model.fit(a.drop('price', axis='columns'), a.price)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1462                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1463             )
#    1464
#    1465             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466                 estimator._validate_params()
#    1467
#    1468             with config_context(
#    1469                 skip_parameter_validation=(
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'

# %%
a.describe
# Out:
# <bound method NDFrame.describe of    area(sq ft)  localilty    price
# 0          550          2  1500000
# 1          600          0  1200000
# 2          650          1   800000
# 3          900          0  3000000
# 4         1000          0  4000000
# 5          800          1  1000000
# 6          900          2  2000000>
